# %% [markdown]
# # 1. 맥도날드 매장 수는 계속 줄어들고 있을까? (202112 202209 2023-05) 최근 3년의 가장 마지막에 업데이트한것을 기준

# %%
import folium
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import matplotlib.pyplot as plt
plt.rc('font',family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
# 2023년 데이터 합치기 (df_2023)

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df_033 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_강원_202303.csv')
df_031 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경기_202303.csv')
df_055 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경남_202303.csv')
df_054 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경북_202303.csv')
df_062 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_광주_202303.csv')
df_053 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_대구_202303.csv')
df_042 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_대전_202303.csv')
df_051 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_부산_202303.csv')

df_02 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_서울_202303.csv')
df_044 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_세종_202303.csv')
df_052 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_울산_202303.csv')
df_032 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_인천_202303.csv')
df_061 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_전남_202303.csv')
df_063 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_전북_202303.csv')
df_064 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_제주_202303.csv')
df_041 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_충남_202303.csv')
df_043 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_충북_202303.csv')

df_2023 =pd.concat([df_02,df_031,df_032,df_033,df_041,df_042,
                     df_043,df_044,df_051,df_052,df_053,
                     df_054,df_055,df_061,df_062,df_063,df_064], axis=0)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-3-2cd29c14504f>:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_033 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_강원_202303.csv')
# <ipython-input-3-2cd29c14504f>:7: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_031 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20230331/소상공인시장진흥공단_상가(상권)정보_경기_202303.csv')
# <ipython-input-3-2cd29c14504f>:8: DtypeWarning: Columns (2,35) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
# 2022년 데이터 합치기 (df_2022)

# %%
df_033 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_강원_202209.csv')
df_031 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경기_202209.csv')
df_055 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경남_202209.csv')
df_054 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경북_202209.csv')
df_062 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_광주_202209.csv')
df_053 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_대구_202209.csv')
df_042 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_대전_202209.csv')
df_051 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_부산_202209.csv')

df_02 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_서울_202209.csv')
df_044 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_세종_202209.csv')
df_052 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_울산_202209.csv')
df_032 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_인천_202209.csv')
df_061 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_전남_202209.csv')
df_063 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_전북_202209.csv')
df_064 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_제주_202209.csv')
df_041 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_충남_202209.csv')
df_043 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_충북_202209.csv')

df_2022 =pd.concat([df_02,df_031,df_032,df_033,df_041,df_042,
                     df_043,df_044,df_051,df_052,df_053,
                     df_054,df_055,df_061,df_062,df_063,df_064], axis=0)
# Out:
# <ipython-input-5-35648e11c767>:3: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_055 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경남_202209.csv')
# <ipython-input-5-35648e11c767>:4: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_054 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_경북_202209.csv')
# <ipython-input-5-35648e11c767>:12: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_052 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20220930/소상공인시장진흥공단_상가(상권)정보_울산_202209.csv')
# ...

# %%
# 2021년 데이터 합치기 (df_2021)

# %%
df_033 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_강원_202112.csv')
df_031 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경기_202112.csv')
df_055 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경남_202112.csv')
df_054 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경북_202112.csv')
df_062 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_광주_202112.csv')
df_053 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_대구_202112.csv')
df_042 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_대전_202112.csv')
df_051 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_부산_202112.csv')

df_02 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_서울_202112.csv')
df_044 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_세종_202112.csv')
df_052 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_울산_202112.csv')
df_032 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_인천_202112.csv')
df_061 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_전남_202112.csv')
df_063 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_전북_202112.csv')
df_064 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_제주_202112.csv')
df_041 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_충남_202112.csv')
df_043 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_충북_202112.csv')

df_2021 =pd.concat([df_02,df_031,df_032,df_033,df_041,df_042,
                     df_043,df_044,df_051,df_052,df_053,
                     df_054,df_055,df_061,df_062,df_063,df_064], axis=0)
# Out:
# <ipython-input-7-9a14d3a673e5>:3: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_055 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경남_202112.csv')
# <ipython-input-7-9a14d3a673e5>:4: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_054 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_경북_202112.csv')
# <ipython-input-7-9a14d3a673e5>:6: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_053 = pd.read_csv('/content/drive/MyDrive/과제 및 시험/소상공인시장진흥공단_상가(상권)정보_20211231/소상공인시장진흥공단_상가(상권)정보_대구_202112.csv')
# ...

# %%
#데이터 정렬(2023년 맥도날드 매장 수 파악하기)
#결측값 제거후 df_2023_MC이란 데이터 프레임 생성

df_2023 = df_2023.dropna(subset=['상호명'],how='any',axis=0)
df_2023_MC= df_2023.loc[df_2023['상호명'].str.contains('맥도날드')]
df_2023_MC

#데이터 정렬(2023년 맥도날드 매장 수 파악하기)
#결측값 제거후 df_2023_MC이란 데이터 프레임 생성

df_2022 = df_2022.dropna(subset=['상호명'],how='any',axis=0)
df_2022_MC= df_2022.loc[df_2022['상호명'].str.contains('맥도날드')]
df_2022_MC

#데이터 정렬(2023년 맥도날드 매장 수 파악하기)
#결측값 제거후 df_2023_MC이란 데이터 프레임 생성

df_2021 = df_2021.dropna(subset=['상호명'],how='any',axis=0)
df_2021_MC= df_2021.loc[df_2021['상호명'].str.contains('맥도날드')]
df_2021_MC
# Out:
#          상가업소번호                 상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 3797   28519789         맥도날드양평SKDT점  양평SKDT점         Q       음식       Q07
# 4039   28519041            맥도날드명지대점     명지대점         Q       음식       Q07
# 4792   20010153                맥도날드      방배점         Q       음식       Q07
# 7710   25796739            맥도날드구의역점     구의역점         Q       음식       Q07
# 10055  19995705                맥도날드      신림점         Q       음식       Q07
# ...         ...                 ...      ...       ...      ...       ...
# 20822  15991960       한국맥도날드제주중문DT점      NaN         Q       음식       Q07
# 26510  20362722              맥킴맥도날드      NaN         Q       음식       Q07
# 26906  12126076                맥도날드    제주성산점         Q       음식       Q07
# 36785  23457993       한국맥도날드제주일도DT점      NaN         Q       음식       Q07
# 37471  25361524  한국맥도날드제주월드컵스타디움DT점      NaN         Q       음식       Q07
#
#       상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
#3개연도 총 점포수 비교를 위해 barplot 작성
plt.bar('2023',len(df_2023_MC),label='Data1')
plt.bar('2022',len(df_2022_MC),label='Data2')
plt.bar('2021',len(df_2021_MC),label='Data3')


plt.text('2023',len(df_2023_MC),len(df_2023_MC))
plt.text('2022',len(df_2022_MC),len(df_2022_MC))
plt.text('2021',len(df_2021_MC),len(df_2021_MC))


plt.xlabel = ('연도')
plt.ylabel = ('맥도날드 개수')


plt.show()

# %% [markdown]
# * 결론: 2021 ~ 2023년 전국 맥도날드 점포수를 취합해서 막대그래프를 그렸을 때
# * 맥도날드 점포 개수가 거시적 관점에서 하락세인 것을 알수 있다.
# * 특히 2021년 ~ 2022년 사이 점포 차이는 -2 지만
# * 2022년 ~ 2023년 사이 점포차이는 -68개로 하락세가 심해진 것을 알 수 있다.
